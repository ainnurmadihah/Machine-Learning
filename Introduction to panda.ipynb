# %%
import pandas as pd

# %%
# 2 main data types
series = pd.Series(["BMW","Toyota","Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimensional

# %%
colours = pd.Series(["Red","Blue","White"])

# %%
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# DataFrame = 2-dimensional
car_data = pd.DataFrame({"Car make": series, "Colour": colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# Import data
car_sales = pd.read_csv("Car_sales.csv")

# %%
car_sales
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
# Exporting a dataframe
car_sales.to_csv("exported_car_sales.csv")

# %%
heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ### Describe data

# %%
# Attributes
car_sales.dtypes

# functions
#car_sales.to_csv()
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands      object
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                   object
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales in thousands', '4-year resale value',
#        'Vehicle type', 'Price in thousands', 'Engine size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb weight', 'Fuel capacity',
#        'Fuel efficiency', 'Latest Launch'],
#       dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales in thousands', '4-year resale value',
#        'Vehicle type', 'Price in thousands', 'Engine size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb weight', 'Fuel capacity',
#        'Fuel efficiency', 'Latest Launch'],
#       dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=157, step=1)

# %%
car_sales
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
car_sales.describe()
# Out:
#        Sales in thousands
# count          157.000000
# mean            52.998076
# std             68.029422
# min              0.110000
# 25%             14.114000
# 50%             29.450000
# 75%             67.956000
# max            540.561000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales in thousands   157 non-null    float64
#  3   4-year resale value  157 non-null    object
#  4   Vehicle type         157 non-null    object
#  5   Price in thousands   157 non-null    object
#  6   Engine size          157 non-null    object
#  7   Horsepower           157 non-null    object
#  8   Wheelbase            157 non-null    object
#  9   Width                157 non-null    object
#  10  Length               157 non-null    object
#  11  Curb weight          157 non-null    object
#  12  Fuel capacity        157 non-null    object
#  13  Fuel efficiency      157 non-null    object
#  14  Latest Launch        157 non-null    object
# ...

# %%
car_prices = pd.Series([3000, 1500, 111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales.sum()
# Out:
# Manufacturer           Acura        Acura        Acura        Acura  ...
# Model                  Integra          TL               CL          ...
# Sales in thousands                                              8320.698
# 4-year resale value    16.3619.87518.22529.72522.25523.55539.28.67536...
# Vehicle type           PassengerPassengerPassengerPassengerPassengerP...
# Price in thousands     21.528.4.4223.9933.956226.9933.438.921.97525.3...
# Engine size            1.83.23.23.51.82.84.22.52.82.83.13.83.83.84.64...
# Horsepower             1402252252101502003101701931931752402052052752...
# Wheelbase              101.2108.1106.9114.6102.6108.7113107.3107.3111...
# Width                  67.370.370.671.468.276.17468.468.570.972.772.7...
# Length                 172.4192.9192196.6178192198.2176176188194.6196...
# Curb weight            2.6393.5173.473.852.9983.5613.9023.1793.1973.4...
# Fuel capacity          13.217.217.21816.418.523.716.616.618.517.517.5...
# ...

# %%
len(car_sales)
# Out:
# 157

# %% [markdown]
# ### Viewing and Selecting Data

# %%
car_sales.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
car_sales
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
car_sales.head(7)
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
# 5  Audi           A6                             18.780              23.555
# 6  Audi           A8                              1.380                  39
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# ...

# %%
car_sales.tail()
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
#     Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 152    Passenger               24.4         1.9        160     100.5  67.6
# 153    Passenger               27.5         2.4        168     104.9  69.3
# 154    Passenger               28.8         2.4        168     104.9  69.3
# 155    Passenger               45.5         2.3        236     104.9  71.5
# 156    Passenger                 36         2.9        201     109.9  72.1
#
# ...

# %%
car_sales.tail(5)
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
#     Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 152    Passenger               24.4         1.9        160     100.5  67.6
# 153    Passenger               27.5         2.4        168     104.9  69.3
# 154    Passenger               28.8         2.4        168     104.9  69.3
# 155    Passenger               45.5         2.3        236     104.9  71.5
# 156    Passenger                 36         2.9        201     109.9  72.1
#
# ...

# %%
# .loc & .iloc
animals = pd.Series(["cat","dog","bird", "panda","snake"], index = [0,3,8,9,3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 8     bird
# 9    panda
# 3    snake
# dtype: object

# %%
# loc refers to index 
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'panda'

# %%
car_sales.loc[3]
# Out:
# Manufacturer               Acura
# Model                  RL
# Sales in thousands                 8.588
# 4-year resale value               29.725
# Vehicle type                   Passenger
# Price in thousands                    42
# Engine size                          3.5
# Horsepower                           210
# Wheelbase                          114.6
# Width                               71.4
# Length                             196.6
# Curb weight                         3.85
# Fuel capacity                         18
# Fuel efficiency                       22
# Latest Launch                   3-Oct-15
# Name: 3, dtype: object

# %%
# iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 8    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 0  172.4       2.639          13.2              28      2-Feb-14
# 1  192.9       3.517          17.2              25      6-Mar-15
# ...

# %%
car_sales.head(4)
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 0  172.4       2.639          13.2              28      2-Feb-14
# 1  192.9       3.517          17.2              25      6-Mar-15
# ...

# %%
car_sales.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
car_sales["Model"]
# Out:
# 0      Integra
# 1      TL
# 2      CL
# 3      RL
# 4      A4
#              ...
# 152    V40
# 153    S70
# 154    V70
# 155    C70
# 156    S80
# Name: Model, Length: 157, dtype: object

# %%
car_sales["Manufacturer"]
# Out:
# 0      Acura
# 1      Acura
# 2      Acura
# 3      Acura
# 4      Audi
#            ...
# 152    Volvo
# 153    Volvo
# 154    Volvo
# 155    Volvo
# 156    Volvo
# Name: Manufacturer, Length: 157, dtype: object

# %%
car_sales[car_sales["Manufacturer"] == "Acura"]
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, 4-year resale value, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch]
# Index: []

# %%
car_sales.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
car_sales[car_sales["Manufacturer"] =="Acura"]
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, 4-year resale value, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch]
# Index: []

# %%
car_sales[car_sales["Length"] ==172]
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, 4-year resale value, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch]
# Index: []

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     513             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     514         except KeyError:
# --> 515             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 'Length'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16896\3218117712.py in ?()
# ----> 1 car_sales.max("Length")
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, axis, skipna, numeric_only, **kwargs)
#   11642             skipna: bool_t = True,
#   11643             numeric_only: bool_t = False,
#   11644             **kwargs,
#   11645         ):
# ...
